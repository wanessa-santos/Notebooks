# %% [markdown]
# <a href="https://colab.research.google.com/github/CharlesPrado23/Notebooks/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Creating new DataFrames - Dictionary

# %%
data={'student': ['João','José','Maria','Ana'], 'year':[1,2,3,1], 'marks':[9.8,6.7,8,9.9]}
dataflair_df=pd.DataFrame(data)
dataflair_df
# Out:
#   student  year  marks
# 0    João     1    9.8
# 1    José     2    6.7
# 2   Maria     3    8.0
# 3     Ana     1    9.9

# %%
mean = dataflair_df['marks'].mean()
#notas = np.array(dataflair_df['marks'])
#media_notas = np.mean(notas)
#print(media_notas)

# %% [markdown]
# # Reading csv from URL

# %%
url = ('https://raw.github.com/pandas-dev'
...: '/pandas/master/pandas/tests/io/data/csv/tips.csv')

# %%
tips = pd.read_csv(url)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# # Type - DataFrame / Series

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
type(tips["smoker"])
# Out:
# pandas.core.series.Series

# %% [markdown]
#    # Creating New DataFrames
#        # Two examples

# %%
df2 = tips[['sex','day']]
df2
# Out:
#         sex   day
# 0    Female   Sun
# 1      Male   Sun
# 2      Male   Sun
# 3      Male   Sun
# 4    Female   Sun
# ..      ...   ...
# 239    Male   Sat
# 240  Female   Sat
# 241    Male   Sat
# 242    Male   Sat
# 243  Female  Thur
#
# [244 rows x 2 columns]

# %%
df3 = tips.sex ## tips['sex']
df3
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: object

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.loc[0:1,'sex']
# Out:
# 0    Female
# 1      Male
# Name: sex, dtype: object

# %%
tips.loc[3,'size']
# Out:
# 2

# %%
tips.iloc[4,0]
# Out:
# 24.59

# %%
tips.iloc[4,2:5]
# Out:
# sex       Female
# smoker        No
# day          Sun
# Name: 4, dtype: object

# %%
tips[['total_bill', 'tip', 'smoker', 'time']].head(5)
# Out:
#    total_bill   tip smoker    time
# 0       16.99  1.01     No  Dinner
# 1       10.34  1.66     No  Dinner
# 2       21.01  3.50     No  Dinner
# 3       23.68  3.31     No  Dinner
# 4       24.59  3.61     No  Dinner

# %%
tips[tips['time'] == 'Dinner'].head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_by_sex = tips.groupby('sex').size()
tips_by_sex
# Out:
# sex
# Female     87
# Male      157
# dtype: int64

# %%
tips_by_sex.plot.bar(rot=0);

# %%
tips_1 = tips.groupby('day').agg({'total_bill': np.max})
tips_1
# Out:
#       total_bill
# day
# Fri        40.17
# Sat        50.81
# Sun        48.17
# Thur       43.11

# %%
tips_1.plot.pie(y='total_bill');

# %%
df1 = pd.DataFrame({'city': ['Chicago', 'San Francisco', 'New York City'], 'rank': range(1, 4)})
df2 = pd.DataFrame({'city': ['Chicago', 'Boston', 'Los Angeles'], 'rank': [1, 4, 5]})

# %%
df1.head()
# Out:
#             city  rank
# 0        Chicago     1
# 1  San Francisco     2
# 2  New York City     3

# %%
df2.head()
# Out:
#           city  rank
# 0      Chicago     1
# 1       Boston     4
# 2  Los Angeles     5

# %%
pd.concat([df1, df2])
# Out:
#             city  rank
# 0        Chicago     1
# 1  San Francisco     2
# 2  New York City     3
# 0        Chicago     1
# 1         Boston     4
# 2    Los Angeles     5

# %%
DataFrame = pd.concat([df1, df2]).drop_duplicates()
DataFrame
# Out:
#             city  rank
# 0        Chicago     1
# 1  San Francisco     2
# 2  New York City     3
# 1         Boston     4
# 2    Los Angeles     5

# %%
DataFrame.reset_index(inplace = True)
DataFrame
# Out:
#    index           city  rank
# 0      0        Chicago     1
# 1      1  San Francisco     2
# 2      2  New York City     3
# 3      1         Boston     4
# 4      2    Los Angeles     5

# %%
tips.to_csv('tips2.csv')

# %%
df_data = pd.read_csv('http://mscbio2025.csb.pitt.edu/files/Spellman.csv')
df_data.columns
# Out:
# Index(['time', '40', '50', '60', '70', '80', '90', '100', '110', '120', '130',
#        '140', '150', '160', '170', '180', '190', '200', '210', '220', '230',
#        '240', '250', '260'],
#       dtype='object')

# %%
df_data.head()
# Out:
#       time     40    50     60    70    80  ...   210   220   230   240   250    260
# 0  YAL001C -0.070 -0.23 -0.100  0.03 -0.04  ... -0.44  0.31  0.03  0.57  0.00  0.010
# 1  YAL014C  0.215  0.09  0.025 -0.04 -0.04  ...  0.13 -0.06 -0.26 -0.10  0.27  0.235
# 2  YAL016W  0.150  0.15  0.220  0.29 -0.10  ...  0.03 -0.26 -0.34 -0.34  0.25  0.190
# 3  YAL020C -0.350 -0.28 -0.215 -0.15  0.16  ... -0.43  0.80 -0.47  1.01 -0.36 -0.405
# 4  YAL022C -0.415 -0.59 -0.580 -0.57 -0.09  ... -0.09  1.03  0.08  0.57 -0.26 -0.310
#
# [5 rows x 24 columns]

# %%
df_data.dtypes
# Out:
# time     object
# 40      float64
# 50      float64
# 60      float64
# 70      float64
# 80      float64
# 90      float64
# 100     float64
# 110     float64
# 120     float64
# 130     float64
# 140     float64
# 150     float64
# 160     float64
# 170     float64
# 180     float64
# 190     float64
# 200     float64
# 210     float64
# 220     float64
# 230     float64
# 240     float64
# 250     float64
# 260     float64
# dtype: object

# %%
df = pd.DataFrame(dict(age=[5, 6, np.NaN],born=[pd.NaT, pd.Timestamp('1939-05-27'),pd.Timestamp('1940-04-25')],
               name=['Alfred', 'Batman', ''],
                  toy=[None, 'Batmobile', 'Joker']))

# %%
df
# Out:
#    age       born    name        toy
# 0  5.0        NaT  Alfred       None
# 1  6.0 1939-05-27  Batman  Batmobile
# 2  NaN 1940-04-25              Joker

# %%
A = df['age']
A
B = A/2
B
# Out:
# 0    2.5
# 1    3.0
# 2    NaN
# Name: age, dtype: float64

# %%
df.isna()
# Out:
#      age   born   name    toy
# 0  False   True  False   True
# 1  False  False  False  False
# 2   True  False  False  False

# %%
df_T = df_data.set_index('time').transpose()
df_T
# Out:
# time  YAL001C  YAL014C  YAL016W  YAL020C  ...  YPR199C  YPR201W  YPR203W  YPR204W
# 40      -0.07    0.215     0.15   -0.350  ...    0.155   -0.255    0.570    0.405
# 50      -0.23    0.090     0.15   -0.280  ...    0.190   -0.360    0.120    0.170
# 60      -0.10    0.025     0.22   -0.215  ...    0.235   -0.300   -0.070   -0.045
# 70       0.03   -0.040     0.29   -0.150  ...    0.280   -0.240   -0.260   -0.260
# 80      -0.04   -0.040    -0.10    0.160  ...   -0.260    1.300   -0.440   -0.600
# 90      -0.12   -0.020     0.15   -0.120  ...    0.210   -0.070   -0.210   -0.090
# 100     -0.28   -0.510    -0.73    0.260  ...   -0.400    0.290   -1.080   -0.850
# 110     -0.44   -0.080     0.19    0.000  ...    0.340   -0.200    0.390    0.170
# 120     -0.09    0.000    -0.15    0.130  ...   -0.800    0.250   -0.170   -0.050
# 130      0.12    0.460     0.29   -0.200  ...    0.340   -0.470    1.610    1.260
# 140      0.06   -0.190    -0.08   -0.070  ...   -0.250    0.230    1.120    0.670
# 150     -0.04    0.040     0.16   -0.050  ...    0.250   -1.200    1.110    0.790
# 160      0.31    0.180    -0.05    0.430  ...   -0.380    0.120    0.290    0.190
# 170      0.59   -0.300     0.12    0.070  ...    0.340   -0.810    0.120    0.170
# 180      0.34   -0.380    -0.17    0.610  ...    0.150    0.890   -0.960   -1.900
# 190     -0.28    0.070     0.11   -0.200  ...    0.300    0.070   -0.310   -0.210
# 200     -0.09   -0.040    -0.15    0.490  ...   -0.060    1.040   -0.810   -0.450
# 210     -0.44    0.130     0.03   -0.430  ...    0.130   -0.320   -0.340   -0.310
# 220      0.31   -0.060    -0.26    0.800  ...   -0.440    0.800   -1.210   -0.390
# 230      0.03   -0.260    -0.34   -0.470  ...   -1.030   -0.130   -1.360   -0.220
# 240      0.57   -0.100    -0.34    1.010  ...    0.140    0.840   -0.120   -0.080
# 250      0.00    0.270     0.25   -0.360  ...    0.300   -0.390    0.690    0.650
# 260      0.01    0.235     0.19   -0.405  ...    0.250   -0.415    0.555    0.520
#
# [23 rows x 4381 columns]

# %%
df_T.columns
# Out:
# Index(['YAL001C', 'YAL014C', 'YAL016W', 'YAL020C', 'YAL022C', 'YAL036C',
#        'YAL038W', 'YAL039C', 'YAL040C', 'YAL044C',
#        ...
#        'YPR189W', 'YPR191W', 'YPR193C', 'YPR194C', 'YPR197C', 'YPR198W',
#        'YPR199C', 'YPR201W', 'YPR203W', 'YPR204W'],
#       dtype='object', name='time', length=4381)

# %%
df_T[['YAL001C','YAL022C','YAL016W','YAL020C','YAL014C']].corr()
# Out:
# time      YAL001C   YAL022C   YAL016W   YAL020C   YAL014C
# time
# YAL001C  1.000000  0.097912 -0.151521  0.568226 -0.164246
# YAL022C  0.097912  1.000000 -0.605068  0.547778 -0.178814
# YAL016W -0.151521 -0.605068  1.000000 -0.564937  0.686653
# YAL020C  0.568226  0.547778 -0.564937  1.000000 -0.402450
# YAL014C -0.164246 -0.178814  0.686653 -0.402450  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
sns.heatmap(df_T[['YAL001C','YAL022C','YAL016W','YAL020C','YAL014C']].corr().round(3))

# %%
plt.scatter(df_T['YAL014C'],df_T['YAL001C'])

# %%
# Out:
# time     YAL001C    YAL014C    YAL016W  ...    YPR201W    YPR203W    YPR204W
# count  23.000000  23.000000  23.000000  ...  23.000000  23.000000  23.000000
# mean    0.006522  -0.013261  -0.003043  ...   0.029130  -0.033261  -0.020000
# std     0.273473   0.220519   0.251910  ...   0.612607   0.770188   0.637946
# min    -0.440000  -0.510000  -0.730000  ...  -1.200000  -1.360000  -1.900000
# 25%    -0.110000  -0.090000  -0.150000  ...  -0.340000  -0.390000  -0.285000
# 50%    -0.040000  -0.020000   0.110000  ...  -0.130000  -0.120000  -0.050000
# 75%     0.090000   0.110000   0.175000  ...   0.270000   0.472500   0.297500
# max     0.590000   0.460000   0.290000  ...   1.300000   1.610000   1.260000
#
# [8 rows x 4381 columns]
